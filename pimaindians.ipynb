# %%
import pandas

data = pandas.read_csv("datasets/pima_indians.csv")
data
# Out:
#      Number Children  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0                  6      148             72             35        0  33.6
# 1                  1       85             66             29        0  26.6
# 2                  8      183             64              0        0  23.3
# 3                  1       89             66             23       94  28.1
# 4                  0      137             40             35      168  43.1
# ..               ...      ...            ...            ...      ...   ...
# 763               10      101             76             48      180  32.9
# 764                2      122             70             27        0  36.8
# 765                5      121             72             23      112  26.2
# 766                1      126             60              0        0  30.1
# 767                1       93             70             31        0  30.4
#
#      Age                  Outcome
# ...

# %%
# describe the data
data.describe()
# Out:
#        Number Children     Glucose  BloodPressure  SkinThickness     Insulin  \
# count       768.000000  768.000000     768.000000     768.000000  768.000000
# mean          3.845052  120.894531      69.105469      20.536458   79.799479
# std           3.369578   31.972618      19.355807      15.952218  115.244002
# min           0.000000    0.000000       0.000000       0.000000    0.000000
# 25%           1.000000   99.000000      62.000000       0.000000    0.000000
# 50%           3.000000  117.000000      72.000000      23.000000   30.500000
# 75%           6.000000  140.250000      80.000000      32.000000  127.250000
# max          17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI         Age
# count  768.000000  768.000000
# mean    31.992578   33.240885
# std      7.884160   11.760232
# min      0.000000   21.000000
# 25%     27.300000   24.000000
# 50%     32.000000   29.000000
# 75%     36.600000   41.000000
# ...

# %%
# separate the data
array = data.values
# print(array)

X=array[:, 0:7]
# print(X)
Y = array[:, 7]
print(Y)
# Out:
# ['Likely to Have Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'Likely to Have Diabetes' 'No Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'Likely to Have Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'Likely to Have Diabetes' 'No Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes'
#  'Likely to Have Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
# ...

# %%
# We split the data even further
from sklearn import model_selection
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X,Y,test_size=0.3, random_state=42)

# %%
# import one of the models
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
# Out:
# SVC()

# %%
# Test the model
predictions = model.predict(X_test)
print("Model predicted: ", predictions)
print("We expected: ", Y_test)
# Out:
# Model predicted:  ['No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes'
#  'No Diabetes' 'Likely to Have Diabetes' 'No Diabetes' 'No Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes'
#  'Likely to Have Diabetes' 'No Diabetes' 'No Diabetes' 'No Diabetes'
#  'No Diabetes' 'Likely to Have Diabetes' 'Likely to Have Diabetes'
#  'Likely to Have Diabetes' 'Likely to Have Diabetes' 'No Diabetes'
#  'Likely to Have Diabetes' 'Likely to Have Diabetes' 'No Diabetes'
#  'No Diabetes' 'Likely to Have Diabetes' 'No Diabetes' 'No Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'No Diabetes' 'No Diabetes' 'Likely to Have Diabetes'
#  'No Diabetes' 'Likely to Have Diabetes' 'No Diabetes' 'No Diabetes'
# ...

# %%
# Test the accuracy score of the model
from sklearn.metrics import accuracy_score
print("Accuracy: ", accuracy_score(Y_test, predictions))
# Out:
# Accuracy:  0.7359307359307359

# %%
outcome = [[4, 13 , 98, 0, 14, 7, 42]]
outcome = model.predict(outcome)
print("You have ", outcome)
# Out:
# You will be having a ['No Diabetes']
